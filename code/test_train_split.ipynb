# %%
import pandas as pd
import numpy

# %%
path = "C:/Users/david/E-15/Programmieren/MotorcycleClassification/"

# %%
# # Import data

df = pd.read_csv(path+"/data/joint_data_collection_1801.csv", index_col="Unnamed: 0")
print(f"Dataset Shape: {df.shape}")
print(f"Spalten: {df.columns.tolist()}")
# y_cols = [
#     "Category_ATV",
#     "Category_Allround",
#     "Category_Classic",
#     "Category_Cross / motocross",
#     "Category_Custom / cruiser",
#     "Category_Enduro / offroad",
#     "Category_Naked bike",
#     "Category_Scooter",
#     "Category_Sport",
#     "Category_Sport touring",
#     "Category_Super motard",
#     "Category_Touring",
#     "Category_Unspecified category"
# ]

# y: Labels
y = 'Category'

# # X: Features (alles außer Kategorien)
# X = df.drop(columns=y_cols)

print(df.dtypes)
# Out:
# Dataset Shape: (17400, 24)
# Spalten: ['Engine type_In-line four, four-stroke', 'Engine type_In-line three, four-stroke', 'Engine type_Single cylinder, four-stroke', 'Engine type_Single cylinder, two-stroke', 'Engine type_Twin, four-stroke', 'Engine type_Twin, two-stroke', 'Engine type_Two cylinder boxer, four-stroke', 'Engine type_V2, four-stroke', 'Engine type_V4, four-stroke', 'Transmission type,final drive_Belt', 'Transmission type,final drive_Chain', 'Transmission type,final drive_Shaft drive (cardan)', 'Front brakes_Double disc', 'Front brakes_Dual disc', 'Front brakes_Expanding brake', 'Front brakes_Expanding brake (drum brake)', 'Front brakes_Single disc', 'Rear brakes_Expanding brake', 'Rear brakes_Expanding brake (drum brake)', 'Rear brakes_Single disc', 'Displacement ccm', 'Fuel capacity liters', 'Power HP', 'Category']
# Engine type_In-line four, four-stroke                 float64
# Engine type_In-line three, four-stroke                float64
# Engine type_Single cylinder, four-stroke              float64
# Engine type_Single cylinder, two-stroke               float64
# Engine type_Twin, four-stroke                         float64
# Engine type_Twin, two-stroke                          float64
# Engine type_Two cylinder boxer, four-stroke           float64
# Engine type_V2, four-stroke                           float64
# Engine type_V4, four-stroke                           float64
# Transmission type,final drive_Belt                    float64
# Transmission type,final drive_Chain                   float64
# Transmission type,final drive_Shaft drive (cardan)    float64
# Front brakes_Double disc                              float64
# Front brakes_Dual disc                                float64
# Front brakes_Expanding brake                          float64
# Front brakes_Expanding brake (drum brake)             float64
# Front brakes_Single disc                              float64
# Rear brakes_Expanding brake                           float64
# Rear brakes_Expanding brake (drum brake)              float64
# Rear brakes_Single disc                               float64
# Displacement ccm                                      float64
# Fuel capacity liters                                  float64
# Power HP                                              float64
# Category                                               object
# dtype: object

# %%
# # # Daten normalisieren => Min Max

# # # Alle Spalten außer 'y' normalisieren
# cols_to_scale = ['Displacement ccm', 'Fuel capacity liters','Power HP']

# df[cols_to_scale] = (df[cols_to_scale] - df[cols_to_scale].min()) / (df[cols_to_scale].max() - df[cols_to_scale].min())

# %%
# Test-Train-Split

df_random = df.sample(frac=1, random_state=42).reset_index(drop=True)

df_activation = df_random.iloc[:10]
df_rest = df_random.iloc[10:]

train_size = int(len(df_rest) * 0.80)
df_train = df_rest.iloc[:train_size]
df_test = df_rest.iloc[train_size:]


#print(df_train.shape)
#print(df_test.shape)

# %%
df_train
# Out:
#        Engine type_In-line four, four-stroke  \
# 10                                       0.0
# 11                                       0.0
# 12                                       0.0
# 13                                       0.0
# 14                                       1.0
# ...                                      ...
# 13917                                    0.0
# 13918                                    0.0
# 13919                                    0.0
# 13920                                    0.0
# 13921                                    1.0
#
#        Engine type_In-line three, four-stroke  \
# 10                                        0.0
# 11                                        0.0
# 12                                        0.0
# 13                                        0.0
# 14                                        0.0
# ...                                       ...
# 13917                                     0.0
# 13918                                     0.0
# 13919                                     0.0
# 13920                                     0.0
# 13921                                     0.0
#
#        Engine type_Single cylinder, four-stroke  \
# 10                                          1.0
# 11                                          1.0
# 12                                          1.0
# 13                                          1.0
# 14                                          0.0
# ...                                         ...
# 13917                                       1.0
# 13918                                       0.0
# 13919                                       1.0
# 13920                                       1.0
# 13921                                       0.0
#
#        Engine type_Single cylinder, two-stroke  Engine type_Twin, four-stroke  \
# 10                                         0.0                            0.0
# 11                                         0.0                            0.0
# 12                                         0.0                            0.0
# 13                                         0.0                            0.0
# 14                                         0.0                            0.0
# ...                                        ...                            ...
# 13917                                      0.0                            0.0
# 13918                                      0.0                            0.0
# 13919                                      0.0                            0.0
# 13920                                      0.0                            0.0
# 13921                                      0.0                            0.0
#
#        Engine type_Twin, two-stroke  \
# 10                              0.0
# 11                              0.0
# 12                              0.0
# 13                              0.0
# 14                              0.0
# ...                             ...
# 13917                           0.0
# 13918                           0.0
# 13919                           0.0
# 13920                           0.0
# 13921                           0.0
#
#        Engine type_Two cylinder boxer, four-stroke  \
# 10                                             0.0
# 11                                             0.0
# 12                                             0.0
# 13                                             0.0
# 14                                             0.0
# ...                                            ...
# 13917                                          0.0
# 13918                                          0.0
# 13919                                          0.0
# 13920                                          0.0
# 13921                                          0.0
#
#        Engine type_V2, four-stroke  Engine type_V4, four-stroke  \
# 10                             0.0                          0.0
# 11                             0.0                          0.0
# 12                             0.0                          0.0
# 13                             0.0                          0.0
# 14                             0.0                          0.0
# ...                            ...                          ...
# 13917                          0.0                          0.0
# 13918                          1.0                          0.0
# 13919                          0.0                          0.0
# 13920                          0.0                          0.0
# 13921                          0.0                          0.0
#
#        Transmission type,final drive_Belt  ...  Front brakes_Expanding brake  \
# 10                                    0.0  ...                           0.0
# 11                                    0.0  ...                           0.0
# 12                                    0.0  ...                           1.0
# 13                                    1.0  ...                           0.0
# 14                                    0.0  ...                           0.0
# ...                                   ...  ...                           ...
# 13917                                 0.0  ...                           0.0
# 13918                                 0.0  ...                           0.0
# 13919                                 0.0  ...                           0.0
# 13920                                 0.0  ...                           0.0
# 13921                                 0.0  ...                           0.0
#
#        Front brakes_Expanding brake (drum brake)  Front brakes_Single disc  \
# 10                                           0.0                       1.0
# 11                                           0.0                       1.0
# 12                                           0.0                       0.0
# 13                                           0.0                       1.0
# 14                                           0.0                       0.0
# ...                                          ...                       ...
# 13917                                        0.0                       0.0
# 13918                                        0.0                       0.0
# 13919                                        0.0                       1.0
# 13920                                        0.0                       1.0
# 13921                                        0.0                       0.0
#
#        Rear brakes_Expanding brake  Rear brakes_Expanding brake (drum brake)  \
# 10                             1.0                                       0.0
# 11                             0.0                                       0.0
# 12                             1.0                                       0.0
# 13                             0.0                                       1.0
# 14                             0.0                                       0.0
# ...                            ...                                       ...
# 13917                          0.0                                       0.0
# 13918                          0.0                                       0.0
# 13919                          0.0                                       0.0
# 13920                          0.0                                       1.0
# 13921                          0.0                                       0.0
#
#        Rear brakes_Single disc  Displacement ccm  Fuel capacity liters  \
# 10                         0.0         -0.505462             -0.436047
# 11                         1.0         -1.006489             -0.723527
# 12                         0.0         -1.128298             -2.256751
# 13                         0.0         -0.951330             -1.700957
# 14                         1.0          0.082899              0.713871
# ...                        ...               ...                   ...
# 13917                      1.0         -0.765169             -1.011006
# 13918                      1.0          0.986125              0.330565
# 13919                      1.0         -0.721501             -0.819353
# 13920                      0.0         -0.719203             -0.627700
# 13921                      1.0          1.381430              0.713871
#
#        Power HP           Category
# 10    -0.538305  Cross / motocross
# 11    -0.908025  Cross / motocross
# 12    -1.054965            Scooter
# 13    -0.993345            Scooter
# 14     0.006794              Sport
# ...         ...                ...
# 13917 -0.796635       Super motard
# 13918  0.848143              Sport
# 13919 -0.687615         Naked bike
# 13920 -0.794265  Cross / motocross
# 13921  1.428792         Naked bike
#
# [13912 rows x 24 columns]

# %%
print(f"Dataset Shape: {df_train.shape}")
print(f"Dataset Shape: {df_test.shape}")
print(f"Dataset Shape: {df_activation.shape}")
# Out:
# Dataset Shape: (13912, 24)
# Dataset Shape: (3478, 24)
# Dataset Shape: (10, 24)

# %%
df_train.to_csv(path+"data/train/training_data.csv", index=False)
df_test.to_csv(path+"data/validation/test_data.csv", index=False)
df_activation.to_csv(path+"images/activationBase_MotorcycleClassification_01/activation_data.csv", index=False)
